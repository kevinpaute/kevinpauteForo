# %% [markdown]
# <center><h1>Inteligencia Artificial</header1></center>

# %% [markdown]
# Presentado por: Kevin Paute  <br>
# Fecha: 27/07/2022

# %% [markdown]
# # Importación de librerias necesarias

# %%
#Para esta actividad se importarán las siguientes librerías:

import pandas as pd # Importar libreria pandas como pd
from sklearn.tree import DecisionTreeClassifier # Importar libreria DecisionTreeClassifier
from sklearn.model_selection import train_test_split # Importar libreria train_test_split
from sklearn import metrics # Importar libreria metrics

# %% [markdown]
# ## Cargar el Dataset

# %%
#Código para cargar el Dataset

data_bank = pd.read_csv("bankfull.csv", sep=";") # Leer el archivo diabetes.csv
data_bank.head()                       # Mostrar los 5 primeros registros
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %% [markdown]
# ## Descripción de la fuente del Dataset

# %% [markdown]
# Los datos están relacionados con campañas de marketing directo de una entidad bancaria portuguesa. Las campañas de marketing están basadas en llamadas telefónicas. De acuerdo al dataset, requería de un contacto con el mismo cliente, para poder acceder si el producto (depósito bancario a plazo) estaría ('sí') o no ('no') suscrito.

# %% [markdown]
# ## Explique el problema a resolver.
#
# **Variables x:**
#
# 1 - age (numeric): edad
#
#
# 2 - job : tipo de trabajo
#
# 3 - marital : estado civil
#
# 4 - education: tipo de educación
#
# 5 - default: tiene credito en mora?
#
# 6 - housing: tiene préstamo de vivienda?
#
# 7 - loan: tiene préstamo personal?
#
# 8 - contact: tipo de comunicación de contacto
#
#
# 9 - month: ultimo mes de contacto
#
# 10 - day_of_week: último día de contacto de la semana
#
# 11 - duration: duración del último contacto, en segundos
#
# 12 - campaign: número de contactos realizados durante esta campaña y para este cliente
#
# 13 - pdays: número de días transcurridos desde la última vez que se contactó al cliente de una campaña anterior
#
# 14 - previous: número de contactos realizados antes de esta campaña y para este cliente (numeric)
#
# 15 - poutcome: resultado de la campaña de marketing anterior
#
# 16 - emp.var.rate: tasa de variación del empleo - indicador trimestral (numérico)
#
# 17 - cons.price.idx: índice de precios al consumidor - indicador mensual (numérico)
#
# 18 - cons.conf.idx: índice de confianza del consumidor - indicador mensual (numérico)
#
# 19 - euribor3m: tasa euribor 3 meses - indicador diario (numeric)
#
# 20 - nr.employed: número de empleados - indicador trimestral (numeric)
#
# **Variable objetivo (target):**
#
# 21 - y : ¿El cliente ha suscrito un depósito a plazo? (binary: 'yes','no')

# %% [markdown]
# ## Caracterización del Dataset
#
# Realice una descripción de los datos con:
#
# >- Número de instancias en total.
# >- Número de atributos de entrada, su significado y tipo.
# >- Estadísticas de la variable objetivo.
# >- Estadísticas los atributos en relación con la variable objetivo.

# %%
#Código que responde a la descripción anterior
df_bank = pd.DataFrame(data_bank)
df_bank.describe()
# Out:
#                age      duration      campaign         pdays      previous  \
# count  41188.00000  41188.000000  41188.000000  41188.000000  41188.000000
# mean      40.02406    258.285010      2.567593    962.475454      0.172963
# std       10.42125    259.279249      2.770014    186.910907      0.494901
# min       17.00000      0.000000      1.000000      0.000000      0.000000
# 25%       32.00000    102.000000      1.000000    999.000000      0.000000
# 50%       38.00000    180.000000      2.000000    999.000000      0.000000
# 75%       47.00000    319.000000      3.000000    999.000000      0.000000
# max       98.00000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  41188.000000    41188.000000   41188.000000  41188.000000  41188.000000
# mean       0.081886       93.575664     -40.502600      3.621291   5167.035911
# ...

# %% [markdown]
# En un par de párrafos haga un resumen de los principales hallazagos encontrados:

# %% [markdown]
# ## Preprocesamiento del dataset. Transformaciones previas necesarias para la modelación

# %%
#Transformación de las caracteristicas (mire el apartado Feature engineering del aula virtual)
cols_caract = ['age', 'duration', 'campaign', 'pdays','previous','emp.var.rate','cons.price.idx', 'euribor3m', 'nr.employed']
X = data_bank[cols_caract] # caracteristicas
y = data_bank.y# target/etiqueta

# %% [markdown]
# ## División del dataset en datos de entrenamiento y datos de test

# %%
#Código que realice la división en entrenamiento y test, de acuerdo con la estretgia de evaluación planeada. Describa cuál es.

#Se inicia el entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)
# Se crea el objeto clasficiador para  Decision Tree
clf = DecisionTreeClassifier()
# Se entrena el clasificador del árbol de decisiones
clf = clf.fit(X_train,y_train)
# Se predice la respuesta para el conjunto de datos de prueba
y_pred = clf.predict(X_test)

# %% [markdown]
# ## Modelamiento

# %%
#Código del modelo

from sklearn.tree import export_graphviz
from six import StringIO 
from IPython.display import Image  
import pydotplus

dot_data = StringIO()
export_graphviz(clf, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True,
                feature_names = feature_cols,
                class_names=['0','1'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png('bankfull.png')
Image(graph.create_png())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14904/4032950260.py in <module>
#       4 from six import StringIO
#       5 from IPython.display import Image
# ----> 6 import pydotplus
#       7
#       8 dot_data = StringIO()
#
# ModuleNotFoundError: No module named 'pydotplus'

# %%
#Entrenamiento
X_train
# Out:
#        age  duration  campaign  pdays  previous  emp.var.rate  cons.price.idx  \
# 11196   38       149         1    999         0           1.4          94.465
# 15464   51       104         1    999         0           1.4          93.918
# 25538   45       770         1    999         0          -0.1          93.200
# 13108   45       394         1    999         0           1.4          93.918
# 17088   34      1000         1    999         0           1.4          93.918
# ...    ...       ...       ...    ...       ...           ...             ...
# 7813    43       114         1    999         0           1.4          94.465
# 32511   42       114         7    999         1          -1.8          92.893
# 5192    36        95         1    999         0           1.1          93.994
# 12172   37       305         1    999         0           1.4          93.918
# 33003   35        83         2    999         1          -1.8          92.893
#
#        euribor3m  nr.employed
# ...

# %%
#Test
X_test
# Out:
#        age  duration  campaign  pdays  previous  emp.var.rate  cons.price.idx  \
# 35577   32       114         1    999         0          -1.8          92.893
# 13950   33       103         2    999         0           1.4          93.918
# 29451   25       227         5    999         0          -1.8          93.075
# 32295   34        56         1    999         0          -1.8          92.893
# 27477   53        11         7    999         0          -0.1          93.200
# ...    ...       ...       ...    ...       ...           ...             ...
# 33344   47       184         3    999         0          -1.8          92.893
# 11690   43      1023         3    999         0           1.4          94.465
# 25695   56        68         1    999         0          -0.1          93.200
# 10932   55       205         4    999         0           1.4          94.465
# 1230    48       521         7    999         0           1.1          93.994
#
#        euribor3m  nr.employed
# ...

# %% [markdown]
# ## Evaluación del Modelo

# %% [markdown]
# Construya un o dos párrafos con los principales hallazgos. Cómo está funcionando el modelo? Calidad en los resultados de predicción.

# %%
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8858137088290038
